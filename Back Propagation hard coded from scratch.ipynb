# %% [markdown]
# # ANMOL GUPTA 20BCB0135
# # Slot : L11+L12
# # Q1 BackPropagation Neural Network from Scratch

# %%
# Initialize a network
def initialize_network(n_inputs, n_hidden, n_outputs):
    network = list()
    hidden_layer = [{'weights':[random() for i in range(n_inputs + 1)]} for i in range(n_hidden)]
    network.append(hidden_layer)
    output_layer = [{'weights':[random() for i in range(n_hidden + 1)]} for i in range(n_outputs)]
    network.append(output_layer)
    return network

# %%
# Calculate neuron activation for an input
def activate(weights, inputs):
    activation = weights[-1]
    for i in range(len(weights)-1):
        activation += weights[i] * inputs[i]
    return activation

# %%
# Transfer neuron activation
from math import exp
def transfer(activation):
    return 1.0 / (1.0 + exp(-activation))

# %%
# Forward propagate input to a network output
def forward_propagate(network, row):
    inputs = row
    for layer in network:
        new_inputs = []
        for neuron in layer:
            activation = activate(neuron['weights'], inputs)
            neuron['output'] = transfer(activation)
            new_inputs.append(neuron['output'])
        inputs = new_inputs
    return inputs

# %%
# Calculate the derivative of an neuron output
def transfer_derivative(output):
    return output * (1.0 - output)

# %%
# Backpropagate error and store in neurons
def backward_propagate_error(network, expected):
    for i in reversed(range(len(network))):
        layer = network[i]
        errors = list()
        if i != len(network)-1:
            for j in range(len(layer)):
                error = 0.0
                for neuron in network[i + 1]:
                    error += (neuron['weights'][j] * neuron['delta'])
                errors.append(error)
        else:
            for j in range(len(layer)):
                neuron = layer[j]
                errors.append(neuron['output'] - expected[j])
        for j in range(len(layer)):
            neuron = layer[j]
            neuron['delta'] = errors[j] * transfer_derivative(neuron['output'])

# %%
# Update network weights with error
def update_weights(network, row, l_rate):
    for i in range(len(network)):
        inputs = row[:-1]
        if i != 0:
            inputs = [neuron['output'] for neuron in network[i - 1]]
        for neuron in network[i]:
            for j in range(len(inputs)):
                neuron['weights'][j] -= l_rate * neuron['delta'] * inputs[j]
            neuron['weights'][-1] -= l_rate * neuron['delta']

# %%
# Train a network for a fixed number of epochs
def train_network(network, train, l_rate, n_epoch, n_outputs):
    for epoch in range(n_epoch):
        sum_error = 0
        for row in train:
            outputs = forward_propagate(network, row)
            expected = [0 for i in range(n_outputs)]
            expected[row[-1]] = 1
            sum_error += sum([(expected[i]-outputs[i])**2 for i in range(len(expected))])
            backward_propagate_error(network, expected)
            update_weights(network, row, l_rate)
            print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))

# %%
# Test training backprop algorithm
from random import random
from random import seed
seed(1)
dataset = [[2.7810836,2.550537003,0],
    [1.465489372,2.362125076,0],
    [3.396561688,4.400293529,0],
    [1.38807019,1.850220317,0],
    [3.06407232,3.005305973,0],
    [7.627531214,2.759262235,1],
    [5.332441248,2.088626775,1],
    [6.922596716,1.77106367,1],
    [8.675418651,-0.242068655,1],
    [7.673756466,3.508563011,1]]
n_inputs = len(dataset[0]) - 1
n_outputs = len(set([row[-1] for row in dataset]))
network = initialize_network(n_inputs, 2, n_outputs)
train_network(network, dataset, 0.5, 20, n_outputs)
for layer in network:
    print(layer)
# Out:
# >epoch=0, lrate=0.500, error=0.502
# >epoch=0, lrate=0.500, error=0.964
# >epoch=0, lrate=0.500, error=1.379
# >epoch=0, lrate=0.500, error=1.763
# >epoch=0, lrate=0.500, error=2.105
# >epoch=0, lrate=0.500, error=2.919
# >epoch=0, lrate=0.500, error=3.643
# >epoch=0, lrate=0.500, error=4.303
# >epoch=0, lrate=0.500, error=4.893
# >epoch=0, lrate=0.500, error=5.411
# >epoch=1, lrate=0.500, error=0.552
# >epoch=1, lrate=0.500, error=1.056
# >epoch=1, lrate=0.500, error=1.521
# >epoch=1, lrate=0.500, error=1.941
# >epoch=1, lrate=0.500, error=2.327
# >epoch=1, lrate=0.500, error=3.021
# >epoch=1, lrate=0.500, error=3.629
# >epoch=1, lrate=0.500, error=4.160
# >epoch=1, lrate=0.500, error=4.621
# >epoch=1, lrate=0.500, error=5.049
# >epoch=2, lrate=0.500, error=0.569
# >epoch=2, lrate=0.500, error=1.077
# >epoch=2, lrate=0.500, error=1.568
# >epoch=2, lrate=0.500, error=1.995
# >epoch=2, lrate=0.500, error=2.405
# >epoch=2, lrate=0.500, error=2.994
# >epoch=2, lrate=0.500, error=3.544
# >epoch=2, lrate=0.500, error=4.026
# >epoch=2, lrate=0.500, error=4.462
# >epoch=2, lrate=0.500, error=4.874
# >epoch=3, lrate=0.500, error=0.563
# >epoch=3, lrate=0.500, error=1.053
# >epoch=3, lrate=0.500, error=1.544
# >epoch=3, lrate=0.500, error=1.955
# >epoch=3, lrate=0.500, error=2.362
# >epoch=3, lrate=0.500, error=2.927
# >epoch=3, lrate=0.500, error=3.469
# >epoch=3, lrate=0.500, error=3.942
# >epoch=3, lrate=0.500, error=4.372
# >epoch=3, lrate=0.500, error=4.780
# >epoch=4, lrate=0.500, error=0.553
# >epoch=4, lrate=0.500, error=1.021
# >epoch=4, lrate=0.500, error=1.506
# >epoch=4, lrate=0.500, error=1.895
# >epoch=4, lrate=0.500, error=2.293
# >epoch=4, lrate=0.500, error=2.853
# >epoch=4, lrate=0.500, error=3.394
# >epoch=4, lrate=0.500, error=3.863
# >epoch=4, lrate=0.500, error=4.288
# >epoch=4, lrate=0.500, error=4.692
# >epoch=5, lrate=0.500, error=0.543
# >epoch=5, lrate=0.500, error=0.991
# >epoch=5, lrate=0.500, error=1.467
# >epoch=5, lrate=0.500, error=1.836
# >epoch=5, lrate=0.500, error=2.220
# >epoch=5, lrate=0.500, error=2.782
# >epoch=5, lrate=0.500, error=3.323
# >epoch=5, lrate=0.500, error=3.785
# >epoch=5, lrate=0.500, error=4.205
# >epoch=5, lrate=0.500, error=4.602
# >epoch=6, lrate=0.500, error=0.535
# >epoch=6, lrate=0.500, error=0.963
# >epoch=6, lrate=0.500, error=1.431
# >epoch=6, lrate=0.500, error=1.779
# >epoch=6, lrate=0.500, error=2.150
# >epoch=6, lrate=0.500, error=2.714
# >epoch=6, lrate=0.500, error=3.253
# >epoch=6, lrate=0.500, error=3.708
# >epoch=6, lrate=0.500, error=4.120
# >epoch=6, lrate=0.500, error=4.511
# >epoch=7, lrate=0.500, error=0.528
# >epoch=7, lrate=0.500, error=0.937
# >epoch=7, lrate=0.500, error=1.398
# >epoch=7, lrate=0.500, error=1.727
# >epoch=7, lrate=0.500, error=2.084
# >epoch=7, lrate=0.500, error=2.651
# >epoch=7, lrate=0.500, error=3.186
# >epoch=7, lrate=0.500, error=3.631
# >epoch=7, lrate=0.500, error=4.034
# >epoch=7, lrate=0.500, error=4.416
# >epoch=8, lrate=0.500, error=0.523
# >epoch=8, lrate=0.500, error=0.913
# >epoch=8, lrate=0.500, error=1.368
# >epoch=8, lrate=0.500, error=1.678
# >epoch=8, lrate=0.500, error=2.022
# >epoch=8, lrate=0.500, error=2.591
# >epoch=8, lrate=0.500, error=3.120
# >epoch=8, lrate=0.500, error=3.553
# >epoch=8, lrate=0.500, error=3.946
# >epoch=8, lrate=0.500, error=4.318
# >epoch=9, lrate=0.500, error=0.518
# >epoch=9, lrate=0.500, error=0.891
# >epoch=9, lrate=0.500, error=1.340
# >epoch=9, lrate=0.500, error=1.631
# >epoch=9, lrate=0.500, error=1.962
# >epoch=9, lrate=0.500, error=2.532
# >epoch=9, lrate=0.500, error=3.052
# >epoch=9, lrate=0.500, error=3.473
# >epoch=9, lrate=0.500, error=3.855
# >epoch=9, lrate=0.500, error=4.217
# >epoch=10, lrate=0.500, error=0.514
# >epoch=10, lrate=0.500, error=0.869
# >epoch=10, lrate=0.500, error=1.312
# >epoch=10, lrate=0.500, error=1.585
# >epoch=10, lrate=0.500, error=1.903
# >epoch=10, lrate=0.500, error=2.474
# >epoch=10, lrate=0.500, error=2.983
# >epoch=10, lrate=0.500, error=3.391
# >epoch=10, lrate=0.500, error=3.761
# >epoch=10, lrate=0.500, error=4.112
# >epoch=11, lrate=0.500, error=0.510
# >epoch=11, lrate=0.500, error=0.847
# >epoch=11, lrate=0.500, error=1.285
# >epoch=11, lrate=0.500, error=1.539
# >epoch=11, lrate=0.500, error=1.844
# >epoch=11, lrate=0.500, error=2.416
# >epoch=11, lrate=0.500, error=2.912
# >epoch=11, lrate=0.500, error=3.306
# >epoch=11, lrate=0.500, error=3.663
# >epoch=11, lrate=0.500, error=4.003
# >epoch=12, lrate=0.500, error=0.506
# >epoch=12, lrate=0.500, error=0.825
# >epoch=12, lrate=0.500, error=1.257
# >epoch=12, lrate=0.500, error=1.494
# >epoch=12, lrate=0.500, error=1.785
# >epoch=12, lrate=0.500, error=2.357
# >epoch=12, lrate=0.500, error=2.839
# >epoch=12, lrate=0.500, error=3.218
# >epoch=12, lrate=0.500, error=3.563
# >epoch=12, lrate=0.500, error=3.891
# >epoch=13, lrate=0.500, error=0.502
# >epoch=13, lrate=0.500, error=0.802
# >epoch=13, lrate=0.500, error=1.230
# >epoch=13, lrate=0.500, error=1.449
# >epoch=13, lrate=0.500, error=1.727
# >epoch=13, lrate=0.500, error=2.297
# >epoch=13, lrate=0.500, error=2.763
# >epoch=13, lrate=0.500, error=3.128
# >epoch=13, lrate=0.500, error=3.459
# >epoch=13, lrate=0.500, error=3.775
# >epoch=14, lrate=0.500, error=0.498
# >epoch=14, lrate=0.500, error=0.780
# >epoch=14, lrate=0.500, error=1.201
# >epoch=14, lrate=0.500, error=1.404
# >epoch=14, lrate=0.500, error=1.668
# >epoch=14, lrate=0.500, error=2.235
# >epoch=14, lrate=0.500, error=2.685
# >epoch=14, lrate=0.500, error=3.035
# >epoch=14, lrate=0.500, error=3.354
# >epoch=14, lrate=0.500, error=3.657
# >epoch=15, lrate=0.500, error=0.494
# >epoch=15, lrate=0.500, error=0.757
# >epoch=15, lrate=0.500, error=1.172
# >epoch=15, lrate=0.500, error=1.359
# >epoch=15, lrate=0.500, error=1.609
# >epoch=15, lrate=0.500, error=2.172
# >epoch=15, lrate=0.500, error=2.605
# >epoch=15, lrate=0.500, error=2.940
# >epoch=15, lrate=0.500, error=3.246
# >epoch=15, lrate=0.500, error=3.537
# >epoch=16, lrate=0.500, error=0.489
# >epoch=16, lrate=0.500, error=0.734
# >epoch=16, lrate=0.500, error=1.142
# >epoch=16, lrate=0.500, error=1.314
# >epoch=16, lrate=0.500, error=1.551
# >epoch=16, lrate=0.500, error=2.107
# >epoch=16, lrate=0.500, error=2.524
# >epoch=16, lrate=0.500, error=2.844
# >epoch=16, lrate=0.500, error=3.136
# >epoch=16, lrate=0.500, error=3.416
# >epoch=17, lrate=0.500, error=0.483
# >epoch=17, lrate=0.500, error=0.710
# >epoch=17, lrate=0.500, error=1.112
# >epoch=17, lrate=0.500, error=1.269
# >epoch=17, lrate=0.500, error=1.493
# >epoch=17, lrate=0.500, error=2.041
# >epoch=17, lrate=0.500, error=2.441
# >epoch=17, lrate=0.500, error=2.747
# >epoch=17, lrate=0.500, error=3.026
# >epoch=17, lrate=0.500, error=3.293
# >epoch=18, lrate=0.500, error=0.477
# >epoch=18, lrate=0.500, error=0.686
# >epoch=18, lrate=0.500, error=1.081
# >epoch=18, lrate=0.500, error=1.224
# >epoch=18, lrate=0.500, error=1.436
# >epoch=18, lrate=0.500, error=1.973
# >epoch=18, lrate=0.500, error=2.358
# >epoch=18, lrate=0.500, error=2.649
# >epoch=18, lrate=0.500, error=2.916
# >epoch=18, lrate=0.500, error=3.171
# >epoch=19, lrate=0.500, error=0.469
# >epoch=19, lrate=0.500, error=0.663
# >epoch=19, lrate=0.500, error=1.049
# >epoch=19, lrate=0.500, error=1.180
# >epoch=19, lrate=0.500, error=1.379
# >epoch=19, lrate=0.500, error=1.905
# >epoch=19, lrate=0.500, error=2.274
# >epoch=19, lrate=0.500, error=2.551
# >epoch=19, lrate=0.500, error=2.805
# >epoch=19, lrate=0.500, error=3.049
# [{'weights': [-0.9344296833915354, 5.415265006528539, 2.119276792401685], 'output': 0.006771107411928539, 'delta': 0.0021043974363796607}, {'weights': [-0.5318170193096409, 1.0495810605392335, 0.5702868778548295], 'output': 0.03215116349123682, 'delta': 0.0035440398078028824}]
# [{'weights': [2.1016548017199077, 1.3278343588003103, -0.7153299338834901], 'output': 0.34008032770023483, 'delta': 0.07632276506014914}, {'weights': [-1.8562634078543176, -0.1503175676074742, 0.6396233936354067], 'output': 0.6424434864963373, 'delta': -0.08213425421145709}]

# %%
# Make a prediction with a network
def predict(network, row):
    outputs = forward_propagate(network, row)
    return outputs.index(max(outputs))

# %%
# Taking weights from the output above
network = [[{'weights': [-0.9344296833915354, 5.415265006528539, 2.119276792401685]}, {'weights': [-0.5318170193096409, 1.0495810605392335, 0.5702868778548295]}],
    [{'weights': [2.1016548017199077, 1.3278343588003103, -0.7153299338834901]}, {'weights': [-1.8562634078543176, -0.1503175676074742, 0.6396233936354067]}]]
for row in dataset:
    prediction = predict(network, row)
    print('Expected=%d, Got=%d' % (row[-1], prediction))
# Out:
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=1
# Expected=0, Got=0
# Expected=0, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=1, Got=1
